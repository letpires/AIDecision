# %% [markdown]
# ## Importações

# %%
import pandas as pd
import json

# %% [markdown]
# ## Carregando `applicants.json`

# %%
# Carregar o arquivo JSON
with open("dados/applicants.json", "r", encoding="utf-8") as file:
    data = json.load(file)

# Lista para armazenar os dados achatados
applicants_list = []

# Iterar sobre cada aplicante no JSON
for applicant_id, details in data.items():
    # Criar dicionário base com o ID do aplicante
    flat_dict = {"id_candidato": applicant_id}
       
    # Iterar sobre cada categoria de informações
    for category, sub_data in details.items():
        if isinstance(sub_data, dict):
            # Se for um dicionário, achatá-lo adicionando o nome da categoria como prefixo
            for key, value in sub_data.items():
                flat_dict[f"{category}_{key}"] = value
        else:
            # Se não for um dicionário, adicionar diretamente
            flat_dict[category] = sub_data
       
    applicants_list.append(flat_dict)

# Criar DataFrame
df = pd.DataFrame(applicants_list)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42482 entries, 0 to 42481
# Data columns (total 58 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   id_candidato                                      42482 non-null  object
#  1   infos_basicas_telefone_recado                     42482 non-null  object
#  2   infos_basicas_telefone                            42482 non-null  object
#  3   infos_basicas_objetivo_profissional               42482 non-null  object
#  4   infos_basicas_data_criacao                        42482 non-null  object
#  5   infos_basicas_inserido_por                        42482 non-null  object
#  6   infos_basicas_email                               42482 non-null  object
#  7   infos_basicas_local                               42482 non-null  object
#  8   infos_basicas_sabendo_de_nos_por                  42482 non-null  object
#  9   infos_basicas_data_atualizacao                    42482 non-null  object
#  10  infos_basicas_codigo_profissional                 42482 non-null  object
#  11  infos_basicas_nome                                42482 non-null  object
#  12  informacoes_pessoais_data_aceite                  42482 non-null  object
#  13  informacoes_pessoais_nome                         42482 non-null  object
#  14  informacoes_pessoais_cpf                          42482 non-null  object
#  15  informacoes_pessoais_fonte_indicacao              42482 non-null  object
#  16  informacoes_pessoais_email                        42482 non-null  object
#  17  informacoes_pessoais_email_secundario             42482 non-null  object
#  18  informacoes_pessoais_data_nascimento              42482 non-null  object
#  19  informacoes_pessoais_telefone_celular             42482 non-null  object
#  20  informacoes_pessoais_telefone_recado              42482 non-null  object
#  21  informacoes_pessoais_sexo                         42482 non-null  object
#  22  informacoes_pessoais_estado_civil                 42482 non-null  object
#  23  informacoes_pessoais_pcd                          42482 non-null  object
#  24  informacoes_pessoais_endereco                     42482 non-null  object
#  25  informacoes_pessoais_skype                        42482 non-null  object
#  26  informacoes_pessoais_url_linkedin                 42482 non-null  object
#  27  informacoes_pessoais_facebook                     42482 non-null  object
#  28  informacoes_profissionais_titulo_profissional     42482 non-null  object
#  29  informacoes_profissionais_area_atuacao            42482 non-null  object
#  30  informacoes_profissionais_conhecimentos_tecnicos  42482 non-null  object
#  31  informacoes_profissionais_certificacoes           42482 non-null  object
#  32  informacoes_profissionais_outras_certificacoes    42482 non-null  object
#  33  informacoes_profissionais_remuneracao             42482 non-null  object
#  34  informacoes_profissionais_nivel_profissional      42482 non-null  object
#  35  formacao_e_idiomas_nivel_academico                42482 non-null  object
#  36  formacao_e_idiomas_nivel_ingles                   42482 non-null  object
#  37  formacao_e_idiomas_nivel_espanhol                 42482 non-null  object
#  38  formacao_e_idiomas_outro_idioma                   42482 non-null  object
#  39  cv_pt                                             42482 non-null  object
#  40  cv_en                                             42482 non-null  object
#  41  formacao_e_idiomas_instituicao_ensino_superior    7209 non-null   object
#  42  formacao_e_idiomas_cursos                         7209 non-null   object
#  43  formacao_e_idiomas_ano_conclusao                  7209 non-null   object
#  44  informacoes_pessoais_download_cv                  5562 non-null   object
#  45  informacoes_profissionais_qualificacoes           944 non-null    object
#  46  informacoes_profissionais_experiencias            944 non-null    object
#  47  formacao_e_idiomas_outro_curso                    809 non-null    object
#  48  cargo_atual_id_ibrati                             944 non-null    object
#  49  cargo_atual_email_corporativo                     944 non-null    object
#  50  cargo_atual_cargo_atual                           944 non-null    object
#  51  cargo_atual_projeto_atual                         944 non-null    object
#  52  cargo_atual_cliente                               944 non-null    object
#  53  cargo_atual_unidade                               944 non-null    object
#  54  cargo_atual_data_admissao                         944 non-null    object
#  55  cargo_atual_data_ultima_promocao                  944 non-null    object
#  56  cargo_atual_nome_superior_imediato                944 non-null    object
#  57  cargo_atual_email_superior_imediato               944 non-null    object
# dtypes: object(58)
# memory usage: 18.8+ MB

# %%
df.head()
# Out:
#   id_candidato infos_basicas_telefone_recado infos_basicas_telefone  \
# 0        31000                                      (11) 97048-2708
# 1        31001                                      (11) 93723-4396
# 2        31002                                      (11) 92399-9824
# 3        31003                                      (11) 98100-1727
# 4        31004                                      (11) 92517-2678
#
#   infos_basicas_objetivo_profissional infos_basicas_data_criacao  \
# 0                                            10-11-2021 07:29:49
# 1             Analista Administrativo        10-11-2021 08:56:16
# 2         Administrativo | Financeiro        10-11-2021 09:01:00
# 3                 Área administrativa        10-11-2021 09:08:13
# 4                                            10-11-2021 09:18:46
#
#   infos_basicas_inserido_por                infos_basicas_email  \
# 0               Luna Correia       carolina_aparecida@gmail.com
# 1              Laura Pacheco           eduardo_rios@hotmail.com
# 2              Laura Pacheco  pedro_henrique_carvalho@gmail.com
# 3              Laura Pacheco         thiago_barbosa@hotmail.com
# 4          Maria Clara Pires        diogo_das_neves@hotmail.com
#
#     infos_basicas_local infos_basicas_sabendo_de_nos_por  \
# 0
# 1  São Paulo, São Paulo                           Outros
# 2  São Paulo, São Paulo                          Anúncio
# 3  São Paulo, São Paulo                 Site de Empregos
# 4
#
#   infos_basicas_data_atualizacao  ... cargo_atual_id_ibrati  \
# 0            10-11-2021 07:29:49  ...                   NaN
# 1            11-11-2021 11:10:31  ...                   NaN
# 2            10-11-2021 11:42:36  ...                   NaN
# 3            10-11-2021 16:04:51  ...                   NaN
# 4            10-11-2021 09:22:03  ...                   NaN
#
#   cargo_atual_email_corporativo cargo_atual_cargo_atual  \
# 0                           NaN                     NaN
# 1                           NaN                     NaN
# 2                           NaN                     NaN
# 3                           NaN                     NaN
# 4                           NaN                     NaN
#
#   cargo_atual_projeto_atual cargo_atual_cliente cargo_atual_unidade  \
# 0                       NaN                 NaN                 NaN
# 1                       NaN                 NaN                 NaN
# 2                       NaN                 NaN                 NaN
# 3                       NaN                 NaN                 NaN
# 4                       NaN                 NaN                 NaN
#
#   cargo_atual_data_admissao cargo_atual_data_ultima_promocao  \
# 0                       NaN                              NaN
# 1                       NaN                              NaN
# 2                       NaN                              NaN
# 3                       NaN                              NaN
# 4                       NaN                              NaN
#
#   cargo_atual_nome_superior_imediato cargo_atual_email_superior_imediato
# 0                                NaN                                 NaN
# 1                                NaN                                 NaN
# 2                                NaN                                 NaN
# 3                                NaN                                 NaN
# 4                                NaN                                 NaN
#
# [5 rows x 58 columns]

# %% [markdown]
# Verificando porque existem algumas colunas (`cargo_atual_id_ibrati`,`cargo_atual_email_corporativo`,  `cargo_atual_cargo_atual`...) sendo que elas não aparecem por exemplo no primeiro id do json.
#
# Então verifiquei primeiro os que não tem NaN pra poder verificar no json e entender quantos ids tem essa info.

# %%
superiores = df[df['cargo_atual_nome_superior_imediato'].notna()]
print(superiores[['id_candidato', 'cargo_atual_nome_superior_imediato']].head())
# Out:
#      id_candidato cargo_atual_nome_superior_imediato
# 544         31544
# 814         31814
# 946         31946
# 1501         9342
# 1634         9475

# %% [markdown]
# Bom, somente 5 ids possuem alguma informação nesses campos. Se formos verificar no json id por id, podemos ver que a maioria da info está nula ou sem nada. Isso indica que talvez possamos remover essas features.

# %%
df[df['id_candidato'] == '31946']
# Out:
#     id_candidato infos_basicas_telefone_recado infos_basicas_telefone  \
# 946        31946                                      (11) 98868-1966
#
#     infos_basicas_objetivo_profissional infos_basicas_data_criacao  \
# 946                   Consultora SAP SD        10-12-2021 09:57:59
#
#     infos_basicas_inserido_por         infos_basicas_email  \
# 946             Yasmin da Rosa  josé_pedro_nunes@gmail.com
#
#       infos_basicas_local infos_basicas_sabendo_de_nos_por  \
# 946  Guarulhos, São Paulo                          Anúncio
#
#     infos_basicas_data_atualizacao  ... cargo_atual_id_ibrati  \
# 946            03-02-2022 18:19:31  ...
#
#     cargo_atual_email_corporativo cargo_atual_cargo_atual  \
# 946
#
#     cargo_atual_projeto_atual cargo_atual_cliente cargo_atual_unidade  \
# 946
#
#     cargo_atual_data_admissao cargo_atual_data_ultima_promocao  \
# 946                31-12-1969                       31-12-1969
#
#     cargo_atual_nome_superior_imediato cargo_atual_email_superior_imediato
# 946
#
# [1 rows x 58 columns]

# %% [markdown]
# ## Carregando `prospects.json`

# %%
# Carregar o arquivo JSON de prospects
with open("dados/prospects.json", "r", encoding="utf-8") as file:
    data_prospects = json.load(file)

# Lista para armazenar os dados achatados
prospects_list = []

# Iterar sobre cada prospect no JSON
for prospect_id, details in data_prospects.items():
    # Criar dicionário base com o ID do prospect
    flat_dict = {"id": prospect_id}
    
    # Iterar sobre cada categoria de informações
    for category, sub_data in details.items():
        if isinstance(sub_data, dict):
            # Se for um dicionário, achatá-lo adicionando o nome da categoria como prefixo
            for key, value in sub_data.items():
                flat_dict[f"{category}_{key}"] = value
        else:
            # Se não for um dicionário, adicionar diretamente
            flat_dict[category] = sub_data
    
    prospects_list.append(flat_dict)

# Criar DataFrame
df_prospects = pd.DataFrame(prospects_list)


df_prospects
# Out:
#           id                                             titulo modalidade  \
# 0       4530                                CONSULTOR CONTROL M
# 1       4531  2021-2607395-PeopleSoft Application Engine-Dom...
# 2       4532
# 3       4533  2021-2605708-Microfocus Application Life Cycle...
# 4       4534  2021-2605711-Microfocus QTP - UFT Automation T...
# ...      ...                                                ...        ...
# 14217  14218                               Java Support Analyst
# 14218  14219
# 14219  14220   Consultor Sênior Especialista SAP LES-TRA - 1433
# 14220  14221            Consultor Sênior Oracle EPM FCCS - 1434
# 14221  14222
#
#                                                prospects
# 0      [{'nome': 'José Vieira', 'codigo': '25632', 's...
# 1      [{'nome': 'Sra. Yasmin Fernandes', 'codigo': '...
# 2                                                     []
# 3      [{'nome': 'Arthur Almeida', 'codigo': '26338',...
# 4      [{'nome': 'Ana Luiza Vieira', 'codigo': '26361...
# ...                                                  ...
# 14217  [{'nome': 'Dr. Vitor Hugo Silva', 'codigo': '4...
# 14218                                                 []
# 14219  [{'nome': 'Ana Cardoso', 'codigo': '16828', 's...
# 14220  [{'nome': 'Maria Eduarda Cassiano', 'codigo': ...
# 14221                                                 []
#
# [14222 rows x 4 columns]

# %%
# Expandindo a coluna prospects que contém lista de dicionários
def expand_prospects(row):
    if not row['prospects']:  # Se a lista estiver vazia
        return pd.DataFrame([{
            'id': row['id'],
            'titulo': row['titulo'],
            'modalidade': row['modalidade'],
            'candidato_nome': None,
            'candidato_codigo': None,
            'situacao_candidado': None,
            'data_candidatura': None,
            'ultima_atualizacao': None,
            'comentario': None,
            'recrutador': None
        }])
    
    # Criar uma lista de dicionários expandidos
    expanded_rows = []
    for prospect in row['prospects']:
        expanded_rows.append({
            'id': row['id'],
            'titulo': row['titulo'],
            'modalidade': row['modalidade'],
            'candidato_nome': prospect.get('nome'),
            'candidato_codigo': prospect.get('codigo'),
            'situacao_candidado': prospect.get('situacao_candidado'),
            'data_candidatura': prospect.get('data_candidatura'),
            'ultima_atualizacao': prospect.get('ultima_atualizacao'),
            'comentario': prospect.get('comentario'),
            'recrutador': prospect.get('recrutador')
        })
    
    return pd.DataFrame(expanded_rows)

# Aplicando a expansão
df_prospects_expanded = pd.concat(df_prospects.apply(expand_prospects, axis=1).tolist(), ignore_index=True)

# Exibindo as primeiras linhas do DataFrame expandido
print("\nPrimeiras linhas do DataFrame de Prospects expandido:")
print(df_prospects_expanded.head())

# Exibindo informações sobre o DataFrame expandido
print("\nInformações do DataFrame de Prospects expandido:")
print(df_prospects_expanded.info())
# Out:
# Primeiras linhas do DataFrame de Prospects expandido:
#      id                                             titulo modalidade  \
# 0  4530                                CONSULTOR CONTROL M
# 1  4530                                CONSULTOR CONTROL M
# 2  4531  2021-2607395-PeopleSoft Application Engine-Dom...
# 3  4531  2021-2607395-PeopleSoft Application Engine-Dom...
# 4  4532
#
#              candidato_nome candidato_codigo           situacao_candidado  \
# 0               José Vieira            25632  Encaminhado ao Requisitante
# 1  Srta. Isabela Cavalcante            25529  Encaminhado ao Requisitante
# 2     Sra. Yasmin Fernandes            25364     Contratado pela Decision
# 3            Alexia Barbosa            25360  Encaminhado ao Requisitante
# 4                      None             None                         None
#
#   data_candidatura ultima_atualizacao  \
# 0       25-03-2021         25-03-2021
# 1       22-03-2021         23-03-2021
# 2       17-03-2021         12-04-2021
# 3       17-03-2021         17-03-2021
# 4             None               None
#
#                                           comentario         recrutador
# 0               Encaminhado para  - PJ R$ 72,00/hora  Ana Lívia Moreira
# 1  encaminhado para  - R$ 6.000,00 – CLT Full , n...  Ana Lívia Moreira
# 2                         Data de Inicio: 12/04/2021   Juliana Cassiano
# 3                                                      Juliana Cassiano
# 4                                               None               None
#
# Informações do DataFrame de Prospects expandido:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56702 entries, 0 to 56701
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  56702 non-null  object
#  1   titulo              56702 non-null  object
#  2   modalidade          56702 non-null  object
#  3   candidato_nome      53759 non-null  object
#  4   candidato_codigo    53759 non-null  object
#  5   situacao_candidado  53759 non-null  object
#  6   data_candidatura    53759 non-null  object
#  7   ultima_atualizacao  53759 non-null  object
#  8   comentario          53759 non-null  object
#  9   recrutador          53759 non-null  object
# dtypes: object(10)
# memory usage: 4.3+ MB
# None

# %%
df_prospects_expanded
# Out:
#           id                                             titulo modalidade  \
# 0       4530                                CONSULTOR CONTROL M
# 1       4530                                CONSULTOR CONTROL M
# 2       4531  2021-2607395-PeopleSoft Application Engine-Dom...
# 3       4531  2021-2607395-PeopleSoft Application Engine-Dom...
# 4       4532
# ...      ...                                                ...        ...
# 56697  14219
# 56698  14220   Consultor Sênior Especialista SAP LES-TRA - 1433
# 56699  14220   Consultor Sênior Especialista SAP LES-TRA - 1433
# 56700  14221            Consultor Sênior Oracle EPM FCCS - 1434
# 56701  14222
#
#                  candidato_nome candidato_codigo           situacao_candidado  \
# 0                   José Vieira            25632  Encaminhado ao Requisitante
# 1      Srta. Isabela Cavalcante            25529  Encaminhado ao Requisitante
# 2         Sra. Yasmin Fernandes            25364     Contratado pela Decision
# 3                Alexia Barbosa            25360  Encaminhado ao Requisitante
# 4                          None             None                         None
# ...                         ...              ...                          ...
# 56697                      None             None                         None
# 56698               Ana Cardoso            16828                     Desistiu
# 56699     Pedro Lucas das Neves            15042  Encaminhado ao Requisitante
# 56700    Maria Eduarda Cassiano            49190                     Prospect
# 56701                      None             None                         None
#
#       data_candidatura ultima_atualizacao  \
# 0           25-03-2021         25-03-2021
# 1           22-03-2021         23-03-2021
# 2           17-03-2021         12-04-2021
# 3           17-03-2021         17-03-2021
# 4                 None               None
# ...                ...                ...
# 56697             None               None
# 56698       26-02-2025         28-02-2025
# 56699       28-02-2025         28-02-2025
# 56700       26-02-2025         26-02-2025
# 56701             None               None
#
#                                               comentario         recrutador
# 0                   Encaminhado para  - PJ R$ 72,00/hora  Ana Lívia Moreira
# 1      encaminhado para  - R$ 6.000,00 – CLT Full , n...  Ana Lívia Moreira
# 2                             Data de Inicio: 12/04/2021   Juliana Cassiano
# 3                                                          Juliana Cassiano
# 4                                                   None               None
# ...                                                  ...                ...
# 56697                                               None               None
# 56698  Recebeu a confirmação de outro processo seleti...        Elisa Nunes
# 56699                                                           Elisa Nunes
# 56700                                                          Luna Correia
# 56701                                               None               None
#
# [56702 rows x 10 columns]

# %% [markdown]
# ## Carregando `vagas.json`

# %%
# Carregar o arquivo JSON de vagas
with open("dados/vagas.json", "r", encoding="utf-8") as file:
    data_vagas = json.load(file)

# Lista para armazenar os dados achatados
vagas_list = []

# Iterar sobre cada vaga no JSON
for vaga_id, details in data_vagas.items():
    # Criar dicionário base com o ID da vaga
    flat_dict = {"id_vaga": vaga_id}
    
    # Iterar sobre cada categoria de informações
    for category, sub_data in details.items():
        if isinstance(sub_data, dict):
            # Se for um dicionário, achatá-lo adicionando o nome da categoria como prefixo
            for key, value in sub_data.items():
                flat_dict[f"{category}_{key}"] = value
        else:
            # Se não for um dicionário, adicionar diretamente
            flat_dict[category] = sub_data
    
    vagas_list.append(flat_dict)

# Criar DataFrame
df_vagas = pd.DataFrame(vagas_list)
df_vagas
# Out:
#       id_vaga informacoes_basicas_data_requicisao  \
# 0        5185                          04-05-2021
# 1        5184                          04-05-2021
# 2        5183                          04-05-2021
# 3        5182                          04-05-2021
# 4        5181                          04-05-2021
# ...       ...                                 ...
# 14076   12368                          28-02-2024
# 14077   12367                          28-02-2024
# 14078   12366                          27-02-2024
# 14079   12365                          27-02-2024
# 14080   12364                          27-02-2024
#
#       informacoes_basicas_limite_esperado_para_contratacao  \
# 0                                             00-00-0000
# 1                                             00-00-0000
# 2                                             00-00-0000
# 3                                             18-05-2021
# 4                                             00-00-0000
# ...                                                  ...
# 14076                                         31-03-2024
# 14077                                         29-02-2024
# 14078                                         29-02-2024
# 14079                                         29-02-2024
# 14080                                         29-02-2024
#
#                          informacoes_basicas_titulo_vaga  \
# 0                                       Operation Lead -
# 1                                 Consultor PP/QM Sênior
# 2                                  ANALISTA PL/JR C/ SQL
# 3                         Technical Architect - 11894809
# 4      Consultor SAP AUTHORIZATION (BCA) -Pleno / Sênior
# ...                                                  ...
# 14076                             PMP 5203658 - Dynamics
# 14077                               MM com IM - FSR 3910
# 14078              964 - Assistente fiscal ou financeiro
# 14079      966 - Analista pleno ou sênior de área fiscal
# 14080      965 - Assistente ou analista de área contábil
#
#       informacoes_basicas_vaga_sap informacoes_basicas_cliente  \
# 0                              Não    Morris, Moran and Dodson
# 1                              Não    Morris, Moran and Dodson
# 2                              Não    Morris, Moran and Dodson
# 3                              Não                 Nelson-Page
# 4                              Não               Mann and Sons
# ...                            ...                         ...
# 14076                          Não                Miller-Curry
# 14077                          Não                 Bishop-Reed
# 14078                          Não   Glover, Warren and Norris
# 14079                          Não   Glover, Warren and Norris
# 14080                          Não   Glover, Warren and Norris
#
#       informacoes_basicas_solicitante_cliente  \
# 0                       Dra. Catarina Marques
# 1                       Dra. Catarina Marques
# 2                       Dra. Catarina Marques
# 3                           Dr. Raul Monteiro
# 4                                 Cauê Fogaça
# ...                                       ...
# 14076                        Guilherme Campos
# 14077                       Lívia Vasconcelos
# 14078                           Lorenzo Cunha
# 14079                           Lorenzo Cunha
# 14080                           Lorenzo Cunha
#
#       informacoes_basicas_empresa_divisao informacoes_basicas_requisitante  \
# 0                      Decision São Paulo             Maria Laura Nogueira
# 1                      Decision São Paulo             Maria Laura Nogueira
# 2                      Decision São Paulo             Maria Laura Nogueira
# 3                      Decision São Paulo                  Cecília Freitas
# 4                      Decision São Paulo             Maria Laura Nogueira
# ...                                   ...                              ...
# 14076                   Decision Campinas            Sra. Juliana Oliveira
# 14077                  Decision São Paulo                   Manuella Jesus
# 14078                  Decision São Paulo                      Maria Lopes
# 14079                  Decision São Paulo                      Maria Lopes
# 14080                  Decision São Paulo                      Maria Lopes
#
#       informacoes_basicas_analista_responsavel  ...  \
# 0                         Srta. Bella Ferreira  ...
# 1                               Yasmin da Rosa  ...
# 2                              Ana Albuquerque  ...
# 3                                   Clara Rios  ...
# 4                         Srta. Bella Ferreira  ...
# ...                                        ...  ...
# 14076                         Sra. Joana Sousa  ...
# 14077                     Srta. Bella Ferreira  ...
# 14078                        Maria Clara Pires  ...
# 14079                        Melina Montenegro  ...
# 14080                            Laura Pacheco  ...
#
#                           perfil_vaga_demais_observacoes  \
# 0                100% Remoto Período – entre 5 – 6 meses
# 1                       • Início: Imediato • Fim: Jan/22
# 2      Localização: Remoto Perfil: Analista Pleno ou ...
# 3      Budgeted Rate - indicate currency and type (ho...
# 4      contratação CLT full pela Decision locação rem...
# ...                                                  ...
# 14076
# 14077                                          FSR: 3910
# 14078  Modelo de trabalho: Hibrido, 3 vezes por seman...
# 14079  Modelo de trabalho: Hibrido, 3 vezes por seman...
# 14080  Modelo de trabalho: Hibrido, 3 vezes por seman...
#
#       perfil_vaga_viagens_requeridas perfil_vaga_equipamentos_necessarios  \
# 0                                                                Nenhum -
# 1                                                                Nenhum -
# 2                                                                Nenhum -
# 3                                Não                    Notebook padrão -
# 4                                Sim                             Nenhum -
# ...                              ...                                  ...
# 14076
# 14077                            Não
# 14078                            Não
# 14079                            Não
# 14080                            Não
#
#       beneficios_valor_venda  \
# 0                          -
# 1                          -
# 2                          -
# 3            - p/ mês (168h)
# 4                          -
# ...                      ...
# 14076               123,00 -
# 14077                  168 -
# 14078                  168 -
# 14079                  168 -
# 14080                  168 -
#
#                                beneficios_valor_compra_1  \
# 0                                                     R$
# 1                                                     R$
# 2                                                     R$
# 3                                                fechado
# 4                                                     R$
# ...                                                  ...
# 14076  APPLICATION DEVELOPER-MICROSOFT ANALYTICS - ba...
# 14077                                            Fechado
# 14078                                            Fechado
# 14079                                            Fechado
# 14080                                            Fechado
#
#       beneficios_valor_compra_2 informacoes_basicas_data_inicial  \
# 0                                                            NaN
# 1                                                            NaN
# 2                                                            NaN
# 3                                                     18-05-2021
# 4                                                            NaN
# ...                         ...                              ...
# 14076                                                        NaN
# 14077                                                        NaN
# 14078                                                        NaN
# 14079                                                        NaN
# 14080                                                        NaN
#
#       informacoes_basicas_data_final  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                         17-01-2022
# 4                                NaN
# ...                              ...
# 14076                            NaN
# 14077                            NaN
# 14078                            NaN
# 14079                            NaN
# 14080                            NaN
#
#       perfil_vaga_habilidades_comportamentais_necessarias  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 14076                                                NaN
# 14077                                                NaN
# 14078                                                NaN
# 14079                                                NaN
# 14080                                                NaN
#
#       informacoes_basicas_nome_substituto
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ...                                   ...
# 14076                                 NaN
# 14077                                 NaN
# 14078                                 NaN
# 14079                                 NaN
# 14080                                 NaN
#
# [14081 rows x 45 columns]

# %% [markdown]
# ## Juntando as tabelas

# %% [markdown]
# `id_vaga` é o mesmo do `id` da tabela de prospects. E na tabela prospects o `codigo_candidato` é ligado ao `id_candidato` da tabela de aplicantes.

# %%
df_prospects_expanded = df_prospects_expanded.rename(columns={'id': 'id_vaga'})

# %%
# Convertendo o id_vaga para string em ambos os DataFrames para garantir compatibilidade
df_vagas['id_vaga'] = df_vagas['id_vaga'].astype(str)
df_prospects_expanded['id_vaga'] = df_prospects_expanded['id_vaga'].astype(str)

# %%
# Unindo vagas com prospects
df_vagas_prospects = pd.merge(
    df_prospects_expanded,
    df_vagas,
    on='id_vaga',
    how='left'
)

# %%
df_vagas_prospects.head()
# Out:
#   id_vaga                                             titulo modalidade  \
# 0    4530                                CONSULTOR CONTROL M
# 1    4530                                CONSULTOR CONTROL M
# 2    4531  2021-2607395-PeopleSoft Application Engine-Dom...
# 3    4531  2021-2607395-PeopleSoft Application Engine-Dom...
# 4    4532
#
#              candidato_nome candidato_codigo           situacao_candidado  \
# 0               José Vieira            25632  Encaminhado ao Requisitante
# 1  Srta. Isabela Cavalcante            25529  Encaminhado ao Requisitante
# 2     Sra. Yasmin Fernandes            25364     Contratado pela Decision
# 3            Alexia Barbosa            25360  Encaminhado ao Requisitante
# 4                      None             None                         None
#
#   data_candidatura ultima_atualizacao  \
# 0       25-03-2021         25-03-2021
# 1       22-03-2021         23-03-2021
# 2       17-03-2021         12-04-2021
# 3       17-03-2021         17-03-2021
# 4             None               None
#
#                                           comentario         recrutador  ...  \
# 0               Encaminhado para  - PJ R$ 72,00/hora  Ana Lívia Moreira  ...
# 1  encaminhado para  - R$ 6.000,00 – CLT Full , n...  Ana Lívia Moreira  ...
# 2                         Data de Inicio: 12/04/2021   Juliana Cassiano  ...
# 3                                                      Juliana Cassiano  ...
# 4                                               None               None  ...
#
#                       perfil_vaga_demais_observacoes  \
# 0  Contratação PJ Projeto pontual de 2 a 3 meses ...
# 1  Contratação PJ Projeto pontual de 2 a 3 meses ...
# 2      Remoto DEPOIS PRESENCIAL, TEMPO INDETERMINADO
# 3      Remoto DEPOIS PRESENCIAL, TEMPO INDETERMINADO
# 4                            APENAS PJ E CLT FULL!!!
#
#   perfil_vaga_viagens_requeridas perfil_vaga_equipamentos_necessarios  \
# 0                                                            Nenhum -
# 1                                                            Nenhum -
# 2                                                   Notebook padrão -
# 3                                                   Notebook padrão -
# 4                                                                 NaN
#
#   beneficios_valor_venda beneficios_valor_compra_1 beneficios_valor_compra_2  \
# 0                      -                        R$
# 1                      -                        R$
# 2                      -                      hora
# 3                      -                      hora
# 4                      -              Valor Aberto
#
#   informacoes_basicas_data_inicial informacoes_basicas_data_final  \
# 0                              NaN                            NaN
# 1                              NaN                            NaN
# 2                              NaN                            NaN
# 3                              NaN                            NaN
# 4                              NaN                            NaN
#
#   perfil_vaga_habilidades_comportamentais_necessarias  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Tempo de projeto = 1 ano\nRequested start date...
#
#   informacoes_basicas_nome_substituto
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
# [5 rows x 54 columns]

# %%
df_final = pd.merge(
    df_vagas_prospects,
    df,
    left_on='candidato_codigo',
    right_on='id_candidato',
    how='left'
)

df_final.head()
# Out:
#   id_vaga                                             titulo modalidade  \
# 0    4530                                CONSULTOR CONTROL M
# 1    4530                                CONSULTOR CONTROL M
# 2    4531  2021-2607395-PeopleSoft Application Engine-Dom...
# 3    4531  2021-2607395-PeopleSoft Application Engine-Dom...
# 4    4532
#
#              candidato_nome candidato_codigo           situacao_candidado  \
# 0               José Vieira            25632  Encaminhado ao Requisitante
# 1  Srta. Isabela Cavalcante            25529  Encaminhado ao Requisitante
# 2     Sra. Yasmin Fernandes            25364     Contratado pela Decision
# 3            Alexia Barbosa            25360  Encaminhado ao Requisitante
# 4                      None             None                         None
#
#   data_candidatura ultima_atualizacao  \
# 0       25-03-2021         25-03-2021
# 1       22-03-2021         23-03-2021
# 2       17-03-2021         12-04-2021
# 3       17-03-2021         17-03-2021
# 4             None               None
#
#                                           comentario         recrutador  ...  \
# 0               Encaminhado para  - PJ R$ 72,00/hora  Ana Lívia Moreira  ...
# 1  encaminhado para  - R$ 6.000,00 – CLT Full , n...  Ana Lívia Moreira  ...
# 2                         Data de Inicio: 12/04/2021   Juliana Cassiano  ...
# 3                                                      Juliana Cassiano  ...
# 4                                               None               None  ...
#
#   cargo_atual_id_ibrati cargo_atual_email_corporativo cargo_atual_cargo_atual  \
# 0                   NaN                           NaN                     NaN
# 1                   NaN                           NaN                     NaN
# 2                   NaN                           NaN                     NaN
# 3                   NaN                           NaN                     NaN
# 4                   NaN                           NaN                     NaN
#
#   cargo_atual_projeto_atual cargo_atual_cliente cargo_atual_unidade  \
# 0                       NaN                 NaN                 NaN
# 1                       NaN                 NaN                 NaN
# 2                       NaN                 NaN                 NaN
# 3                       NaN                 NaN                 NaN
# 4                       NaN                 NaN                 NaN
#
#   cargo_atual_data_admissao cargo_atual_data_ultima_promocao  \
# 0                       NaN                              NaN
# 1                       NaN                              NaN
# 2                       NaN                              NaN
# 3                       NaN                              NaN
# 4                       NaN                              NaN
#
#   cargo_atual_nome_superior_imediato cargo_atual_email_superior_imediato
# 0                                NaN                                 NaN
# 1                                NaN                                 NaN
# 2                                NaN                                 NaN
# 3                                NaN                                 NaN
# 4                                NaN                                 NaN
#
# [5 rows x 112 columns]

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56702 entries, 0 to 56701
# Columns: 112 entries, id_vaga to cargo_atual_email_superior_imediato
# dtypes: object(112)
# memory usage: 48.5+ MB

# %%
df_final.to_csv('merged_data.csv', index=False)
